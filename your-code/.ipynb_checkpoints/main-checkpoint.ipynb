# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('seaborn')

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data_original = data.copy()
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
item_type = data[['ItemType', 'RetailSales', 'RetailTransfers', 'WarehouseSales']]
item_type.describe()
# Out:
#          RetailSales  RetailTransfers  WarehouseSales
# count  128355.000000    128355.000000   128355.000000
# mean        6.563037         7.188161       22.624213
# std        28.924944        30.640156      239.693277
# min        -6.490000       -27.660000    -4996.000000
# 25%         0.000000         0.000000        0.000000
# 50%         0.330000         0.000000        1.000000
# 75%         3.250000         4.000000        4.000000
# max      1616.600000      1587.990000    16271.750000

# %%
item_type = item_type.groupby(['ItemType'], as_index = False).sum()
item_type
# Out:
#        ItemType  RetailSales  RetailTransfers  WarehouseSales
# 0          BEER    209763.11        234924.44      2437617.32
# 1       DUNNAGE         0.00             0.00       -45331.00
# 2          KEGS         0.00             0.00        43558.00
# 3        LIQUOR    309847.85        334176.41        33173.32
# 4   NON-ALCOHOL      8109.97          9058.37         8656.72
# 5           REF       281.34           171.92        -6754.00
# 6  STR_SUPPLIES       995.98          3594.70            0.00
# 7          WINE    313400.42        340710.51       433009.47

# %%
plt.figure(figsize=(17,6))
item_type.plot.bar(x="ItemType", y=["RetailSales", "RetailTransfers", "WarehouseSales"])
plt.ylim(-50000, 2500000)
plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
top_10 = data_original.copy()

# %%
top_10['total_sales'] = top_10['RetailSales'] + top_10['WarehouseSales'] + top_10['RetailTransfers']

# %%
top_10 = top_10.groupby(['Supplier'], as_index = False).sum()

# %%
top_10
# Out:
#                        Supplier      Year  Month  RetailSales  \
# 0                    8 VINI INC     18154     72         2.78
# 1               A HARDY USA LTD      6051     26         0.40
# 2          A I G WINE & SPIRITS     80687    303        12.52
# 3         A VINTNERS SELECTIONS  17581913  62637      8640.57
# 4                       A&E INC     76652    297        11.52
# ..                          ...       ...    ...          ...
# 328                 WINEBOW INC     14119     70         1.24
# 329       YOUNG WON TRADING INC   1559290   5525      1058.65
# 330           YUENGLING BREWERY    336872   1171      9628.35
# 331  Z WINE GALLERY IMPORTS LLC     60516    209         8.83
# 332                  ZURENA LLC     18155     63        16.15
#
#      RetailTransfers  WarehouseSales  total_sales
# 0               2.00            1.00         5.78
# 1               0.00            0.00         0.40
# 2               5.92          134.00       152.44
# ...

# %%
top_10 = top_10.sort_values(by=['total_sales'], ascending=False)

# %%
top_10 = top_10.reset_index()

# %%
top_10 = top_10.iloc[0:10,]

# %%
top_10
# Out:
#    index                  Supplier     Year  Month  RetailSales  \
# 0    184    MILLER BREWING COMPANY  2602210   8980     35022.63
# 1     69             CROWN IMPORTS   812941   2800     26707.83
# 2     15        ANHEUSER BUSCH INC  4322888  15170     42559.14
# 3    139              HEINEKEN USA   982381   3412     20923.17
# 4     94        E & J GALLO WINERY  9418283  32124     67455.63
# 5     78  DIAGEO NORTH AMERICA INC  6723330  23122     57656.36
# 6     65      CONSTELLATION BRANDS  5751015  19663     54472.51
# 7    150        JIM BEAM BRANDS CO  5533195  18869     39156.79
# 8    288            THE WINE GROUP  3570439  12196     25758.15
# 9     38   BOSTON BEER CORPORATION  1061051   3692     10773.25
#
#    RetailTransfers  WarehouseSales  total_sales
# 0         39176.67       572623.41    646822.71
# 1         29561.67       579824.70    636094.20
# 2         47322.64       493856.19    583737.97
# 3         23004.25       318812.59    362740.01
# ...

# %%
plt.figure(figsize=(17,6))
top_10.plot.barh(x="Supplier", y=["RetailSales", "RetailTransfers", "WarehouseSales"])
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
sales_evolution = data_original.copy()

# %%
sales_evolution['Day'] = 1

# %%
sales_evolution['Date'] = pd.to_datetime(sales_evolution[['Year', 'Month', 'Day']])

# %%
sales_evolution = sales_evolution.groupby(['Date'], as_index = False).agg("mean")

# %%
plt.figure(figsize=(17,6))
plt.plot(sales_evolution.Date, sales_evolution.RetailSales, 'blue', label='Retail Sales', linewidth=2)
plt.plot(sales_evolution.Date, sales_evolution.RetailTransfers, 'red', label='Retail Transfers', linewidth=2)
plt.plot(sales_evolution.Date, sales_evolution.WarehouseSales, 'green', label='Warehouse Sales', linewidth=2)
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
plt.figure(figsize=(17,6))
sales_evolution.plot.bar(x="Date", y=["RetailSales", "RetailTransfers", "WarehouseSales"])
plt.show()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
retail_over_time = data_original.copy()

# %%
retail_over_time.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
retail_over_time['Day'] = 1
retail_over_time['Date'] = pd.to_datetime(retail_over_time[['Year', 'Month', 'Day']])

# %%
retail_over_time = retail_over_time.groupby(['Date', 'ItemType']).sum()

# %%
retail_over_time = retail_over_time[['RetailSales']]

# %%
retail_over_time.head(10)
# Out:
#                          RetailSales
# Date       ItemType
# 2017-04-01 BEER                 0.00
#            LIQUOR               0.00
#            NON-ALCOHOL          0.00
#            REF                  0.00
#            STR_SUPPLIES         0.00
#            WINE                 0.00
# 2017-05-01 BEER             25023.24
#            LIQUOR           35123.36
#            WINE             34546.89
# 2017-06-01 BEER             27863.26

# %%
unstack_retail_over_time = retail_over_time.unstack()

# %%
unstack_retail_over_time.plot(figsize=(15,6))
plt.show()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
unstack_retail_over_time.plot(figsize=(15,6), kind='bar')
plt.show()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
retail_relationship = data_original.copy()

# %%
retail_relationship
# Out:
#         Year  Month                      Supplier ItemCode  \
# 0       2017      4               ROYAL WINE CORP   100200
# 1       2017      4      SANTA MARGHERITA USA INC   100749
# 2       2017      4            JIM BEAM BRANDS CO    10103
# 3       2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4               ROYAL WINE CORP   101664
# ...      ...    ...                           ...      ...
# 128350  2018      2            ANHEUSER BUSCH INC     9997
# 128351  2018      2   COASTAL BREWING COMPANY LLC    99970
# 128352  2018      2       BOSTON BEER CORPORATION    99988
# 128353  2018      2                           NaN       BC
# 128354  2018      2                           NaN       WC
#
#                                     Description ItemType  RetailSales  \
# 0                             GAMLA CAB - 750ML     WINE         0.00
# 1          SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE         0.00
# ...

# %%
plt.figure(figsize=(17,6))
sns.lmplot(x="RetailSales", y="RetailTransfers", hue="ItemType", height=5, aspect=3, data=retail_relationship, fit_reg=False)
plt.show()

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
scatter_matrix = data_original.copy()

# %%
sns.pairplot(scatter_matrix, hue="ItemType")
